# %% [markdown]
# # Strands Agents with Bedrock AgentCore Browser
#
# This workshop demonstrates how to integrate Strands Agents with Amazon Bedrock AgentCore Browser to create AI agents capable of interacting with web browsers dynamically.
#
# ## Overview
#
# In this lab, you will:
#
# - Learn about Bedrock AgentCore Browser capabilities
# - Test browser automation with Strands Agents
# - Navigate websites and extract information programmatically
# - Explore common use cases for browser automation
# - Understand best practices for web interaction

# %% [markdown]
# ## Prerequisites
#
# Before starting this lab, ensure you have:
#
# - AWS credentials configured (IAM role or environment variables)
# - Required Python packages installed
# - Nova Pro model ID based on AWS region
#
# If you're not running in an environment with an IAM role assumed, set your AWS credentials as environment variables:

# %%
# %env AWS_REGION=<Bedrock AgentCore Region>
# %env AWS_ACCESS_KEY_ID=<YOUR ACCESS KEY>
# %env AWS_SECRET_ACCESS_KEY=<YOUR SECRET KEY>
# %env AWS_SESSION_TOKEN=<OPTIONAL - YOUR SESSION TOKEN IF TEMP CREDENTIAL>
# %env AWS_PROFILE=<OPTIONAL - Your profile configured in ~/.aws/config>

# %%
import os
os.environ["AWS_DEFAULT_REGION"] = "us-east-1"
os.environ["AWS_PROFILE"] = "sso-genai"

# %% [markdown]
# Install required packages for Strands Agents, Playwright and Bedrock AgentCore Python SDK:

# %%
#%pip install -q strands-agents 'strands-agents-tools[agent_core_browser]' bedrock-agentcore playwright rich

# %% [markdown]
# Setup Nova Pro model ID based on AWS region:

# %%
import boto3

region = boto3.session.Session().region_name

NOVA_PRO_MODEL_ID = "us.amazon.nova-pro-v1:0"
if region.startswith("eu"):
    NOVA_PRO_MODEL_ID = "eu.amazon.nova-pro-v1:0"
elif region.startswith("ap"):
    NOVA_PRO_MODEL_ID = "apac.amazon.nova-pro-v1:0"

print(f"Nova Pro Model ID: {NOVA_PRO_MODEL_ID}")
# Out:
# Nova Pro Model ID: us.amazon.nova-pro-v1:0

# %% [markdown]
# ## What is Bedrock AgentCore Browser?
#
# Amazon Bedrock AgentCore Browser is a powerful tool that enables AI agents to interact with web browsers dynamically in a secure, managed environment. Key capabilities include:
#
# - **Web Navigation**: Navigate to websites, click elements, and fill forms programmatically
# - **Content Extraction**: Extract information from web pages and capture screenshots
# - **Secure Environment**: Runs in an isolated, secure browser environment
# - **JavaScript Execution**: Execute custom JavaScript for advanced web interactions
# - **Session Management**: Maintain browser sessions across multiple operations
#
# The Browser tool enables agents to perform complex web-based tasks that require visual understanding and interactive capabilities.

# %% [markdown]
# ### Accessing Browser Session
#
# First let's explore the AgentCore Browser tool without any agentic environment.  We will use the Playwright library to connect to the remote browser session.
#
# Once connected, we can start interacting with the page elements as if it's a real user.

# %%
import boto3
import rich
from bedrock_agentcore.tools.browser_client import browser_session
from playwright.async_api import async_playwright
from IPython.display import display_jpeg

console = rich.get_console()
region = boto3.Session().region_name or "us-east-1"

with browser_session(region) as client:
    console.print(f"🌐 Using AgentCore Browser Session: {client.session_id}", style="cyan")
    ws_url, headers = client.generate_ws_headers()

    async with async_playwright() as playwright:
        chromium = playwright.chromium
        browser = await chromium.connect_over_cdp(endpoint_url=ws_url, headers=headers)
        console.print("[green]✅ Browser connected.[/green]")

        context = browser.contexts[0] if browser.contexts else await browser.new_context()
        page = context.pages[0] if context.pages else await context.new_page()

        console.print("[cyan]🔄 Navigating to AWS Builder Center[/cyan]")
        await page.goto("https://builder.aws.com/")
        await page.wait_for_timeout(5000)
        display_jpeg(await page.screenshot(), raw=True)

        console.print("[cyan]🔄 Clicking on the first article in the spotlight[/cyan]")
        await page.click(".swiper-wrapper div a")
        await page.wait_for_timeout(5000)
        display_jpeg(await page.screenshot(), raw=True)
# Out:
# 🌐 Using AgentCore Browser Session: 01M237GCXV1SB9X014XSA1WVB3
# ✅ Browser connected.
# 🔄 Navigating to AWS Builder Center
# 🔄 Clicking on the first article in the spotlight
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# Cell In[5], line 28
#      24         await page.wait_for_timeout(5000)
#      25         display_jpeg(await page.screenshot(), raw=True)
#      26
#      27         console.print("[cyan]🔄 Clicking on the first article in the spotlight[/cyan]")
# ---> 28         await page.click(".swiper-wrapper div a")
#      29         await page.wait_for_timeout(5000)
#      30         display_jpeg(await page.screenshot(), raw=True)
#
# File ~/Library/CloudStorage/OneDrive-Personal/101.aws_courses/01.GenAI.AWS.Courses/GenAiDemos/02.agentcore.demos/.venv/lib/python3.14/site-packages/playwright/async_api/_generated.py:11026, in Page.click(self, selector, modifiers, position, delay, button, click_count, timeout, force, no_wait_after, trial, strict, scroll)
#   11022             viewport. This is useful to assert that an element is reachable by the user without additional scrolling.
#   11023         """
#   11024
#   11025         return mapping.from_maybe_impl(
# > 11026             await self._impl_obj.click(
#   11027                 selector=selector,
#   11028                 modifiers=mapping.to_impl(modifiers),
#   11029                 position=position,
#
# File ~/Library/CloudStorage/OneDrive-Personal/101.aws_courses/01.GenAI.AWS.Courses/GenAiDemos/02.agentcore.demos/.venv/lib/python3.14/site-packages/playwright/_impl/_page.py:887, in Page.click(self, selector, modifiers, position, delay, button, clickCount, timeout, force, noWaitAfter, trial, strict, scroll)
#     872 async def click(
#     873     self,
#     874     selector: str,
#    (...)    885     scroll: Literal["auto", "none"] = None,
#     886 ) -> None:
# --> 887     return await self._main_frame._click(**locals_to_params(locals()))
#
# File ~/Library/CloudStorage/OneDrive-Personal/101.aws_courses/01.GenAI.AWS.Courses/GenAiDemos/02.agentcore.demos/.venv/lib/python3.14/site-packages/playwright/_impl/_frame.py:593, in Frame._click(self, selector, modifiers, position, delay, button, clickCount, timeout, force, noWaitAfter, strict, trial, steps, scroll)
#     577 async def _click(
#     578     self,
#     579     selector: str,
#    (...)    591     scroll: Literal["auto", "none"] = None,
#     592 ) -> None:
# --> 593     await self._channel.send("click", self._timeout, locals_to_params(locals()))
#
# File ~/Library/CloudStorage/OneDrive-Personal/101.aws_courses/01.GenAI.AWS.Courses/GenAiDemos/02.agentcore.demos/.venv/lib/python3.14/site-packages/playwright/_impl/_connection.py:76, in Channel.send(self, method, timeout_calculator, params, is_internal, title)
#      68 async def send(
#      69     self,
#      70     method: str,
#    (...)     74     title: str = None,
#      75 ) -> Any:
# ---> 76     return await self._connection.wrap_api_call(
#      77         lambda: self._inner_send(method, timeout_calculator, params, False),
#      78         is_internal,
#      79         title,
#      80     )
#
# File ~/Library/CloudStorage/OneDrive-Personal/101.aws_courses/01.GenAI.AWS.Courses/GenAiDemos/02.agentcore.demos/.venv/lib/python3.14/site-packages/playwright/_impl/_connection.py:632, in Connection.wrap_api_call(self, cb, is_internal, title)
#     630     return await cb()
#     631 except Exception as error:
# --> 632     raise rewrite_error(error, f"{parsed_st['apiName']}: {error}") from None
#     633 finally:
#     634     self._api_zone.set(None)
#
# TimeoutError: Page.click: Timeout 30000ms exceeded.
# Call log:
#   - waiting for locator(".swiper-wrapper div a")
#     - locator resolved to 14 elements. Proceeding with the first one: <a rel="noopener" data-analytics-funnel-value="button_r_59_" data-analytics-performance-mark="30-1788962427947-1424" href="/content/3INJ4miNJzex0c3YRxNY4CDehgQ/agents-for-humans-hackathon-build-ai-agents-that-improve-everyday-life" class="awsui_button_vjswe_38vi7_70 awsui_variant-inline-link_vjswe_38vi7_305 awsui_full-width_vjswe_38vi7_533 awsui_link_vjswe_38vi7_584">…</a>
#   - attempting click action
#     2 × waiting for element to be visible, enabled and stable
#       - element is visible, enabled and stable
#       - scrolling into view if needed
#       - done scrolling
#       - <nav aria-label="Side Navigation" class="_app-side-navigation_nb6ot_2">…</nav> from <div class="_layout-navigation_1236f_268">…</div> subtree intercepts pointer events
#     - retrying click action
#     - waiting 20ms
#     - waiting for element to be visible, enabled and stable
#     - element is visible, enabled and stable
#     - scrolling into view if needed
#     - done scrolling
#     - <nav aria-label="Side Navigation" class="_app-side-navigation_nb6ot_2">…</nav> from <div class="_layout-navigation_1236f_268">…</div> subtree intercepts pointer events
#   2 × retrying click action
#       - waiting 100ms
#       - waiting for element to be visible, enabled and stable
#       - element is visible, enabled and stable
#       - scrolling into view if needed
#       - done scrolling
#       - <header class="_page-header_1236f_117">…</header> intercepts pointer events
#   - retrying click action
#     - waiting 500ms
#     - waiting for element to be visible, enabled and stable
#     - element is visible, enabled and stable
#     - scrolling into view if needed
#     - done scrolling
#     - <nav aria-label="Side Navigation" class="_app-side-navigation_nb6ot_2">…</nav> from <div class="_layout-navigation_1236f_268">…</div> subtree intercepts pointer events
#   23 × retrying click action
#        - waiting 500ms
#        - waiting for element to be visible, enabled and stable
#        - element is visible, enabled and stable
#        - scrolling into view if needed
#        - done scrolling
#        - element is outside of the viewport
#   - retrying click action
#     - waiting 500ms

# %% [markdown]
# ### Testing Strands Agent with Browser Automation
#
# Let's demonstrate the Strands Agent using AgentCore Browser for web automation. We'll navigate to Amazon, search for coffee makers, and extract detailed product information from the first result.

# %%
import boto3
import rich
from strands import Agent
from strands.models import BedrockModel
from strands_tools.browser import AgentCoreBrowser


console = rich.get_console()
region = boto3.Session().region_name or "us-east-1"

agentcore_browser = AgentCoreBrowser(region=region)

agent = Agent(
    model=BedrockModel(model_id=NOVA_PRO_MODEL_ID),
    tools=[agentcore_browser.browser],
)

response = await agent.invoke_async("Go to https://builder.aws.com/learn/topics/amazon-bedrock-agentcore, once the page has loaded find the first link that goes to path starting with '/content' and click on it, once the page has loaded, retrieve the page html and summarize the article")

console.print(response.message["content"][0]["text"] if "text" in response.message["content"][0] else "")
# Out:
# <thinking> To complete this task, I need to follow these steps:
# 1. Initialize a new browser session.
# 2. Navigate to the specified URL.
# 3. Once the page has loaded, find the first link that starts with '/content' and click on it.
# 4. After the new page has loaded, retrieve the HTML content of the page.
# 5. Summarize the article based on the retrieved HTML content. </thinking>
#
#
# Tool #1: browser
# <thinking> The browser session has been successfully initialized. The next step is to navigate to the specified URL. </thinking>
# Tool #2: browser
# <thinking> The page has been successfully loaded. The next step is to find the first link that starts with '/content' and click on it. </thinking>
# Tool #3: browser
# <thinking> The first link that starts with '/content' has been found. The next step is to click on this link. </thinking>
# Tool #4: browser
# <thinking> The link has been successfully clicked. The next step is to retrieve the HTML content of the new page. </thinking>
# Tool #5: browser
# <thinking> The HTML content of the new page has been successfully retrieved. The next step is to summarize the article based on the retrieved HTML content. </thinking>
#
# <thinking> The article discusses the author's experience with fine-tuning local LLMs as a student, highlighting the challenges and expenses involved. The author explains why they switched to using Amazon Bedrock, which changed their approach to generative AI prototyping and orchestration. The article emphasizes the benefits of using Amazon Bedrock, such as cost-effectiveness and ease of use for students and developers. </thinking>
#
# The article "Why I stopped trying to train models from scratch (and started using AWS Bedrock as a student)" discusses the author's journey from attempting to fine-tune local Large Language Models (LLMs) to adopting Amazon Bedrock. As a student, the author found that fine-tuning local LLMs was not only time-consuming but also expensive. The article highlights the challenges faced during this process, such as the high costs associated with computational resources and the complexity of managing the fine-tuning process.
#
# The author then explains their transition to using Amazon Bedrock, a service provided by AWS that simplifies the process of building and deploying machine learning models. The article outlines the benefits of using Amazon Bedrock, including its cost-effectiveness, ease of use, and the ability to quickly prototype and orchestrate generative AI applications. The author emphasizes that Amazon Bedrock allowed them to focus more on the application development rather than the underlying infrastructure.
#
# In summary, the article serves as a testimonial for the advantages of using Amazon Bedrock, particularly for students and developers who may not have the resources to fine-tune models from scratch. It underscores the value of leveraging cloud-based services to accelerate the development and deployment of machine learning applications.
# <thinking> The HTML content of the new page has been successfully retrieved. The next step is to summarize the
# article based on the retrieved HTML content. </thinking>
#
# <thinking> The article discusses the author's experience with fine-tuning local LLMs as a student, highlighting the
# challenges and expenses involved. The author explains why they switched to using Amazon Bedrock, which changed
# their approach to generative AI prototyping and orchestration. The article emphasizes the benefits of using Amazon
# Bedrock, such as cost-effectiveness and ease of use for students and developers. </thinking>
#
# The article "Why I stopped trying to train models from scratch (and started using AWS Bedrock as a student)"
# discusses the author's journey from attempting to fine-tune local Large Language Models (LLMs) to adopting Amazon
# Bedrock. As a student, the author found that fine-tuning local LLMs was not only time-consuming but also expensive.
# The article highlights the challenges faced during this process, such as the high costs associated with
# computational resources and the complexity of managing the fine-tuning process.
#
# The author then explains their transition to using Amazon Bedrock, a service provided by AWS that simplifies the
# process of building and deploying machine learning models. The article outlines the benefits of using Amazon
# Bedrock, including its cost-effectiveness, ease of use, and the ability to quickly prototype and orchestrate
# generative AI applications. The author emphasizes that Amazon Bedrock allowed them to focus more on the application
# development rather than the underlying infrastructure.
#
# In summary, the article serves as a testimonial for the advantages of using Amazon Bedrock, particularly for
# students and developers who may not have the resources to fine-tune models from scratch. It underscores the value
# of leveraging cloud-based services to accelerate the development and deployment of machine learning applications.

# %% [markdown]
# Let's examine the detailed execution flow of the agent loop to understand how the agent processes requests and generates responses:

# %%
from rich.table import Table
import rich
import json

console = rich.get_console()

console.print("Agent Loop Detail")
console.rule()
console.print(f"Number of Loops: {agent.event_loop_metrics.cycle_count}")

table = Table(title="Agent Messages", show_lines=True)
table.add_column("Role", style="green")
table.add_column("Text", style="white")
table.add_column("Tool Name", style="yellow")
table.add_column("Tool Input", style="cyan")
table.add_column("Tool Result", style="cyan")

for message in agent.messages:
    text = [content["text"] for content in message["content"] if "text" in content]
    tool_name = [content["toolUse"]["name"] for content in message["content"] if "toolUse" in content]
    tool_input = [content["toolUse"]["input"] for content in message["content"] if "toolUse" in content]
    tool_result = [content["toolResult"]["content"][0] for content in message["content"] if "toolResult" in content]
    table.add_row(message["role"], text[-1] if text else "", 
                  tool_name[-1] if tool_name else "", 
                  json.dumps(tool_input[-1], indent=2) if tool_input else "", 
                  (json.dumps(tool_result[-1], indent=2)[:500]+"\n.\n.\n." if len(str(tool_result[-1])) > 500 else json.dumps(tool_result[-1], indent=2)) if tool_result else "")

console.print(table)
# Out:
# Agent Loop Detail
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Number of Loops: 6
#                                                   Agent Messages
# ┏━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Role      ┃ Text                        ┃ Tool Name ┃ Tool Input                  ┃ Tool Result                 ┃
# ┡━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ user      │ Go to                       │           │                             │                             │
# │           │ https://builder.aws.com/le… │           │                             │                             │
# │           │ once the page has loaded    │           │                             │                             │
# │           │ find the first link that    │           │                             │                             │
# │           │ goes to path starting with  │           │                             │                             │
# │           │ '/content' and click on it, │           │                             │                             │
# │           │ once the page has loaded,   │           │                             │                             │
# │           │ retrieve the page html and  │           │                             │                             │
# │           │ summarize the article       │           │                             │                             │
# ├───────────┼─────────────────────────────┼───────────┼─────────────────────────────┼─────────────────────────────┤
# │ assistant │ <thinking> To complete this │ browser   │ {                           │                             │
# │           │ task, I need to follow      │           │   "browser_input": {        │                             │
# │           │ these steps:                │           │     "action": {             │                             │
# │           │ 1. Initialize a new browser │           │       "type":               │                             │
# │           │ session.                    │           │ "init_session",             │                             │
# │           │ 2. Navigate to the          │           │       "description":        │                             │
# │           │ specified URL.              │           │ "Session to navigate and    │                             │
# │           │ 3. Once the page has        │           │ interact with AWS Builder   │                             │
# │           │ loaded, find the first link │           │ page",                      │                             │
# │           │ that starts with '/content' │           │       "session_name":       │                             │
# │           │ and click on it.            │           │ "aws-builder-session"       │                             │
# │           │ 4. After the new page has   │           │     }                       │                             │
# │           │ loaded, retrieve the HTML   │           │   }                         │                             │
# │           │ content of the page.        │           │ }                           │                             │
# │           │ 5. Summarize the article    │           │                             │                             │
# │           │ based on the retrieved HTML │           │                             │                             │
# │           │ content. </thinking>        │           │                             │                             │
# │           │                             │           │                             │                             │
# │           │                             │           │                             │                             │
# ├───────────┼─────────────────────────────┼───────────┼─────────────────────────────┼─────────────────────────────┤
# │ user      │                             │           │                             │ {                           │
# │           │                             │           │                             │   "json": {                 │
# │           │                             │           │                             │     "sessionName":          │
# │           │                             │           │                             │ "aws-builder-session",      │
# │           │                             │           │                             │     "description": "Session │
# │           │                             │           │                             │ to navigate and interact    │
# │           │                             │           │                             │ with AWS Builder page"      │
# │           │                             │           │                             │   }                         │
# │           │                             │           │                             │ }                           │
# ├───────────┼─────────────────────────────┼───────────┼─────────────────────────────┼─────────────────────────────┤
# │ assistant │ <thinking> The browser      │ browser   │ {                           │                             │
# │           │ session has been            │           │   "browser_input": {        │                             │
# │           │ successfully initialized.   │           │     "action": {             │                             │
# │           │ The next step is to         │           │       "type": "navigate",   │                             │
# │           │ navigate to the specified   │           │       "url":                │                             │
# │           │ URL. </thinking>            │           │ "https://builder.aws.com/l… │                             │
# │           │                             │           │       "session_name":       │                             │
# │           │                             │           │ "aws-builder-session"       │                             │
# │           │                             │           │     }                       │                             │
# │           │                             │           │   }                         │                             │
# │           │                             │           │ }                           │                             │
# ├───────────┼─────────────────────────────┼───────────┼─────────────────────────────┼─────────────────────────────┤
# │ user      │                             │           │                             │ {                           │
# │           │                             │           │                             │   "text": "Navigated to     │
# │           │                             │           │                             │ https://builder.aws.com/le… │
# │           │                             │           │                             │ }                           │
# ├───────────┼─────────────────────────────┼───────────┼─────────────────────────────┼─────────────────────────────┤
# │ assistant │ <thinking> The page has     │ browser   │ {                           │                             │
# │           │ been successfully loaded.   │           │   "browser_input": {        │                             │
# │           │ The next step is to find    │           │     "action": {             │                             │
# │           │ the first link that starts  │           │       "type": "get_text",   │                             │
# │           │ with '/content' and click   │           │       "session_name":       │                             │
# │           │ on it. </thinking>          │           │ "aws-builder-session",      │                             │
# │           │                             │           │       "selector": "a"       │                             │
# │           │                             │           │     }                       │                             │
# │           │                             │           │   }                         │                             │
# │           │                             │           │ }                           │                             │
# ├───────────┼─────────────────────────────┼───────────┼─────────────────────────────┼─────────────────────────────┤
# │ user      │                             │           │                             │ {                           │
# │           │                             │           │                             │   "text": "Text content:    │
# │           │                             │           │                             │ Why I stopped trying to     │
# │           │                             │           │                             │ train models from scratch   │
# │           │                             │           │                             │ (and started using AWS      │
# │           │                             │           │                             │ Bedrock as a student)"      │
# │           │                             │           │                             │ }                           │
# ├───────────┼─────────────────────────────┼───────────┼─────────────────────────────┼─────────────────────────────┤
# │ assistant │ <thinking> The first link   │ browser   │ {                           │                             │
# │           │ that starts with '/content' │           │   "browser_input": {        │                             │
# │           │ has been found. The next    │           │     "action": {             │                             │
# │           │ step is to click on this    │           │       "type": "click",      │                             │
# │           │ link. </thinking>           │           │       "session_name":       │                             │
# │           │                             │           │ "aws-builder-session",      │                             │
# │           │                             │           │       "selector": "a"       │                             │
# │           │                             │           │     }                       │                             │
# │           │                             │           │   }                         │                             │
# │           │                             │           │ }                           │                             │
# ├───────────┼─────────────────────────────┼───────────┼─────────────────────────────┼─────────────────────────────┤
# │ user      │                             │           │                             │ {                           │
# │           │                             │           │                             │   "text": "Clicked element: │
# │           │                             │           │                             │ a"                          │
# │           │                             │           │                             │ }                           │
# ├───────────┼─────────────────────────────┼───────────┼─────────────────────────────┼─────────────────────────────┤
# │ assistant │ <thinking> The link has     │ browser   │ {                           │                             │
# │           │ been successfully clicked.  │           │   "browser_input": {        │                             │
# │           │ The next step is to         │           │     "action": {             │                             │
# │           │ retrieve the HTML content   │           │       "type": "get_html",   │                             │
# │           │ of the new page.            │           │       "session_name":       │                             │
# │           │ </thinking>                 │           │ "aws-builder-session"       │                             │
# │           │                             │           │     }                       │                             │
# │           │                             │           │   }                         │                             │
# │           │                             │           │ }                           │                             │
# ├───────────┼─────────────────────────────┼───────────┼─────────────────────────────┼─────────────────────────────┤
# │ user      │                             │           │                             │ {                           │
# │           │                             │           │                             │   "text": "<!DOCTYPE        │
# │           │                             │           │                             │ html><html lang=\"en\"      │
# │           │                             │           │                             │ dir=\"ltr\"><head><script   │
# │           │                             │           │                             │ src=\"https://a0.awsstatic… │
# │           │                             │           │                             │ fetchpriority=\"auto\"></s… │
# │           │                             │           │                             │ src=\"/__runtime-env.js\">… │
# │           │                             │           │                             │ charset=\"UTF-8\"><link     │
# │           │                             │           │                             │ rel=\"icon\"                │
# │           │                             │           │                             │ type=\"image/svg+xml\"      │
# │           │                             │           │                             │ href=\"/assets/builder-fav… │
# │           │                             │           │                             │ name=\"viewport\"           │
# │           │                             │           │                             │ content=\"width=device-wid… │
# │           │                             │           │                             │ name=\"description\"        │
# │           │                             │           │                             │ content=\"Fine-tuning local │
# │           │                             │           │                             │ LLMs as a student gets      │
# │           │                             │           │                             │ expensive fast. Here is why │
# │           │                             │           │                             │ .                           │
# │           │                             │           │                             │ .                           │
# │           │                             │           │                             │ .                           │
# ├───────────┼─────────────────────────────┼───────────┼─────────────────────────────┼─────────────────────────────┤
# │ assistant │ <thinking> The HTML content │           │                             │                             │
# │           │ of the new page has been    │           │                             │                             │
# │           │ successfully retrieved. The │           │                             │                             │
# │           │ next step is to summarize   │           │                             │                             │
# │           │ the article based on the    │           │                             │                             │
# │           │ retrieved HTML content.     │           │                             │                             │
# │           │ </thinking>                 │           │                             │                             │
# │           │                             │           │                             │                             │
# │           │ <thinking> The article      │           │                             │                             │
# │           │ discusses the author's      │           │                             │                             │
# │           │ experience with fine-tuning │           │                             │                             │
# │           │ local LLMs as a student,    │           │                             │                             │
# │           │ highlighting the challenges │           │                             │                             │
# │           │ and expenses involved. The  │           │                             │                             │
# │           │ author explains why they    │           │                             │                             │
# │           │ switched to using Amazon    │           │                             │                             │
# │           │ Bedrock, which changed      │           │                             │                             │
# │           │ their approach to           │           │                             │                             │
# │           │ generative AI prototyping   │           │                             │                             │
# │           │ and orchestration. The      │           │                             │                             │
# │           │ article emphasizes the      │           │                             │                             │
# │           │ benefits of using Amazon    │           │                             │                             │
# │           │ Bedrock, such as            │           │                             │                             │
# │           │ cost-effectiveness and ease │           │                             │                             │
# │           │ of use for students and     │           │                             │                             │
# │           │ developers. </thinking>     │           │                             │                             │
# │           │                             │           │                             │                             │
# │           │ The article "Why I stopped  │           │                             │                             │
# │           │ trying to train models from │           │                             │                             │
# │           │ scratch (and started using  │           │                             │                             │
# │           │ AWS Bedrock as a student)"  │           │                             │                             │
# │           │ discusses the author's      │           │                             │                             │
# │           │ journey from attempting to  │           │                             │                             │
# │           │ fine-tune local Large       │           │                             │                             │
# │           │ Language Models (LLMs) to   │           │                             │                             │
# │           │ adopting Amazon Bedrock. As │           │                             │                             │
# │           │ a student, the author found │           │                             │                             │
# │           │ that fine-tuning local LLMs │           │                             │                             │
# │           │ was not only time-consuming │           │                             │                             │
# │           │ but also expensive. The     │           │                             │                             │
# │           │ article highlights the      │           │                             │                             │
# │           │ challenges faced during     │           │                             │                             │
# │           │ this process, such as the   │           │                             │                             │
# │           │ high costs associated with  │           │                             │                             │
# │           │ computational resources and │           │                             │                             │
# │           │ the complexity of managing  │           │                             │                             │
# │           │ the fine-tuning process.    │           │                             │                             │
# │           │                             │           │                             │                             │
# │           │ The author then explains    │           │                             │                             │
# │           │ their transition to using   │           │                             │                             │
# │           │ Amazon Bedrock, a service   │           │                             │                             │
# │           │ provided by AWS that        │           │                             │                             │
# │           │ simplifies the process of   │           │                             │                             │
# │           │ building and deploying      │           │                             │                             │
# │           │ machine learning models.    │           │                             │                             │
# │           │ The article outlines the    │           │                             │                             │
# │           │ benefits of using Amazon    │           │                             │                             │
# │           │ Bedrock, including its      │           │                             │                             │
# │           │ cost-effectiveness, ease of │           │                             │                             │
# │           │ use, and the ability to     │           │                             │                             │
# │           │ quickly prototype and       │           │                             │                             │
# │           │ orchestrate generative AI   │           │                             │                             │
# │           │ applications. The author    │           │                             │                             │
# │           │ emphasizes that Amazon      │           │                             │                             │
# │           │ Bedrock allowed them to     │           │                             │                             │
# │           │ focus more on the           │           │                             │                             │
# │           │ application development     │           │                             │                             │
# │           │ rather than the underlying  │           │                             │                             │
# │           │ infrastructure.             │           │                             │                             │
# │           │                             │           │                             │                             │
# │           │ In summary, the article     │           │                             │                             │
# │           │ serves as a testimonial for │           │                             │                             │
# │           │ the advantages of using     │           │                             │                             │
# │           │ Amazon Bedrock,             │           │                             │                             │
# │           │ particularly for students   │           │                             │                             │
# │           │ and developers who may not  │           │                             │                             │
# │           │ have the resources to       │           │                             │                             │
# │           │ fine-tune models from       │           │                             │                             │
# │           │ scratch. It underscores the │           │                             │                             │
# │           │ value of leveraging         │           │                             │                             │
# │           │ cloud-based services to     │           │                             │                             │
# │           │ accelerate the development  │           │                             │                             │
# │           │ and deployment of machine   │           │                             │                             │
# │           │ learning applications.      │           │                             │                             │
# └───────────┴─────────────────────────────┴───────────┴─────────────────────────────┴─────────────────────────────┘

# %% [markdown]
# ### Cleanup Resources

# %%
client = boto3.client("bedrock-agentcore")

args = {"browserIdentifier": "aws.browser.v1", "status": "READY"}
while True:
    response = client.list_browser_sessions(**args)
    for session in response["items"]:
        client.stop_browser_session(
            browserIdentifier=args["browserIdentifier"], sessionId=session["sessionId"]
        )

    if "NextToken" in response:
        args["NextToken"] = response["NextToken"]
    else:
        break

# %% [markdown]
# ## Common Use Cases for Bedrock AgentCore Browser
#
# Beyond web search, Bedrock AgentCore Browser enables a wide variety of automation scenarios:
#
# ### Web Application Testing
#
# - Test web applications in a secure environment
# - Validate user interfaces and functionality
# - Perform automated quality assurance
#
# ### Data Collection & Monitoring
#
# - Extract information from websites
# - Monitor website changes and updates
# - Capture screenshots and record browser sessions
#
# ### Business Process Automation
#
# - Automate form submissions and data entry
# - Perform e-commerce transactions
# - Access online resources and services
#
# ### AI-Powered Web Interaction
#
# - Build AI agents that can navigate the web
# - Interact with web interfaces intelligently
# - Perform web-based tasks and workflows
#
# **Additional Resources:**
# [Bedrock AgentCore Browser Use Cases Examples](https://docs.aws.amazon.com/bedrock-agentcore/latest/devguide/browser-use-cases.html#browser-use-cases-examples)
